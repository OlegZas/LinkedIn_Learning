# %% [markdown]
# **Importing DuckDB into Jupyter notebooks and running SQL.**

# %%
import duckdb

# Load SQL extension to run sql queries in this notebook 
# %load_ext sql

# Initialize 🦆 DuckDB connection
conn = duckdb.connect()

# Import database
# %sql conn --alias duckdb #%sql allows you to run SQL commands directly in your Jupyter notebook. 
# The --alias duckdb part provides an alias (duckdb) that is associated with the conn object, which is the active connection to DuckDB.
# %sql IMPORT DATABASE '../../data/nps';
# Out:
# Loading configurations from /workspaces/fundamentals-of-data-transformation-4554074/pyproject.toml.
# Settings changed:
# +--------------+-------+
# |    Config    | value |
# +--------------+-------+
# |   feedback   |  True |
# |  autopandas  |  True |
# | displaylimit |   10  |
# |  displaycon  | False |
# +--------------+-------+
#    Count
# 0    224

# %%
# %%sql
# DESCRIBE
# #SELECT
#  #   *
# #FROM nps_public_data.parks
# #LIMIT 1
# Out:
#    database           schema                           name  \
# 0    memory  nps_public_data                         events
# 1    memory  nps_public_data                     feespasses
# 2    memory  nps_public_data                    lessonplans
# 3    memory  nps_public_data                           meta
# 4    memory  nps_public_data              multimedia__audio
# 5    memory  nps_public_data          multimedia__galleries
# 6    memory  nps_public_data  multimedia__galleries__assets
# 7    memory  nps_public_data             multimedia__videos
# 8    memory  nps_public_data                   newsreleases
# 9    memory  nps_public_data                     park_hours
# 10   memory  nps_public_data                    parkinglots
# 11   memory  nps_public_data                          parks
# 12   memory  nps_public_data         passportstamplocations
# 13   memory  nps_public_data                         people
# 14   memory  nps_public_data                         places
# ...

# %%
# %%sql
# SELECT
#     fullName as full_name,
#     weatherInfo as weather_info,
#     operatingHours as operating_hours
# FROM nps_public_data.parks as not_parks
# LIMIT 3
# Out:
#                                full_name  \
# 0         Federal Hall National Memorial
# 1  Lewis & Clark National Historic Trail
# 2            National Capital Parks-East
#
#                                         weather_info  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
#
#                                      operating_hours
# 0  [{'name': 'Hours of Operation', 'standardHours...
# 1  [{'name': 'Visitor Center Hours', 'standardHou...
# 2  [{'name': 'National Capital Parks-East Headqua...

# %%
# %%sql
# SHOW ALL TABLES
